# %%
#Área del rectángulo
b=2  #base
h=3  #altura
area=b*h
print("El área del rectángulo es "+str(area))
# Out:
# El área del rectángulo es 6

# %%
#Área del triángulo
b=4
h=8
area=b*h/2
print("El área del triángulo es "+str(area))
# Out:
# El área del triángulo es 16.0

# %%
#Área del círculo
r=4
rcuad=4**2
pi=3.1416
area= pi*rcuad
print ("El área del círculo es "+str(area))
# Out:
# El área del círculo es 50.2656

# %%
#Área del trapecio
bmen=2
bmay=6
h=8
sumbas=bmen+bmay
area=sumbas*h/2
print ("El área del trapecio es "+str(area))
# Out:
# El área del trapecio es 32.0
